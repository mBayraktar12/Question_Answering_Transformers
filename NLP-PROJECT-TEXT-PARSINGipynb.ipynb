# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1-) OPEN AND LOAD THE DATA

# %%
with open("/content/drive/MyDrive/Colab Notebooks/NLP_PROJECT/QAs-2.txt") as f:
  text = f.read()

# %%
text
# Out:
# '1\tAbstraction is generalizing concepts. Engineers can use this for calculating abstract things. This helps for engineers to solving abstract problems. abstraction is useful for think easily\n2\t"İnvested Zero. and then invested number. First of all binary system. then we calculate some science and math problems with this invested.\n"\n3\tthere is a famous line :  today\'s abstract math is tomorrow\' s applied. Which means that  we developed math .and better way to express things  with abstract math.\n4\tAbstraction is one of the greatest tool of the engineer. By abstracting a problem we can solve little pieces of a bigger problem and connect all of the at the end.\n5\t"Before abstract Math is today\'s proven science". Some ideas can be abstract now, however it might be proven by other scientists in the future. So it is important to get a development.\n6\twith abstraction we can understand things that difficualt to understandd approximation law  by infinity instant change abstract p
# ...

# %% [markdown]
# 2-) SPELL CORRECTION

# %%
# !pip install pyspellchecker

# %%
from spellchecker import SpellChecker
 
spell = SpellChecker()

# %%
text = spell.correction(text)
print(text)

# %% [markdown]
# 3-) PUNCTUATION CORRECTION

# %%
# !pip install deepmultilingualpunctuation

# %%
from deepmultilingualpunctuation import PunctuationModel

# %%
# !pip install transformers

# %%
# !pip install sentencepiece

# %%
model = PunctuationModel()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/pipelines/token_classification.py:136: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="none"` instead.
#   "`grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to"

# %%
result = model.restore_punctuation(str(text))
print(result)
# Out:
# 1: Abstraction is generalizing concepts. Engineers can use this for calculating abstract things. This helps for engineers to solving abstract problems. abstraction is useful for think easily. 2: "İnvested Zero and then invested number. First of all binary system. then we calculate some science and math problems with this invested ". 3: there is a famous line: today's abstract math is tomorrow' s applied, Which means that we developed math and better way to express things with abstract math. 4: Abstraction is one of the greatest tool of the engineer. By abstracting a problem we can solve little pieces of a bigger problem and connect all of the at the end. 5: "Before, abstract Math is today's proven science". Some ideas can be abstract now. however, it might be proven by other scientists in the future. So it is important to get a development. 6: with abstraction we can understand things that difficualt to understandd. approximation law by infinity, instant change, abstract predict inte
# ...

# %% [markdown]
# 4-) SPELL CORRECTION WITH ANOTHER MODULE
#
# This module is used because it gives better results than the previous module.

# %%
# !sudo apt-get install swig

# %%
# !pip install jamspell

# %%
import jamspell

# %%
corrector = jamspell.TSpellCorrector()

# %%
corrector.LoadLangModel('en.bin')
text = corrector.FixFragment(result)

# %%
text
# Out:
# '1: Abstraction is generalizing concepts. Engineers can use this for calculating abstract things. This helps for engineers to solving abstract problems. abstraction is useful for think easily. 2: "İnvested Zero and then invested number. First of all binary system. then we calculate some science and math problems with this invested ". 3: there is a famous line: today\'s abstract math is tomorrow\' s applied, Which means that we developed math and better way to express things with abstract math. 4: Abstraction is one of the greatest tool of the engineer. By abstracting a problem we can solve little pieces of a bigger problem and connect all of the at the end. 5: "Before, abstract Math is today\'s proven science". Some ideas can be abstract now. however, it might be proven by other scientists in the future. So it is important to get a development. 6: with abstraction we can understand things that difficualt to understandd. approximation law by infinity, instant change, abstract predict 
# ...

# %% [markdown]
# 5-) REMOVING NUMBERS AND COLONS

# %%
text = ''.join([i for i in text if not i.isdigit()])

# %%
text = text.replace(":","")
text
# Out:
# ' Abstraction is generalizing concepts. Engineers can use this for calculating abstract things. This helps for engineers to solving abstract problems. abstraction is useful for think easily.  "İnvested Zero and then invested number. First of all binary system. then we calculate some science and math problems with this invested ".  there is a famous line today\'s abstract math is tomorrow\' s applied, Which means that we developed math and better way to express things with abstract math.  Abstraction is one of the greatest tool of the engineer. By abstracting a problem we can solve little pieces of a bigger problem and connect all of the at the end.  "Before, abstract Math is today\'s proven science". Some ideas can be abstract now. however, it might be proven by other scientists in the future. So it is important to get a development.  with abstraction we can understand things that difficualt to understandd. approximation law by infinity, instant change, abstract predict interest, app
# ...

# %%
# !pip install language-tool-python

# %% [markdown]
# 6-) GRAMMAR CORRECTION

# %%
import language_tool_python
tool = language_tool_python.LanguageTool('en-US')

# %%
text = tool.correct(text)

# %%
text
# Out:
# ' Abstraction is generalizing concepts. Engineers can use this for calculating abstract things. This helps for engineers to solving abstract problems. Abstraction is useful for think easily.  "Invested Zero and then invested number. First binary system. Then we calculate some science and math problems with this invested ".  There is a famous line today\'s abstract math is tomorrow\'s applied, Which means that we developed math and better way to express things with abstract math.  Abstraction is one of the greatest tool of the engineer. By abstracting a problem we can solve little pieces of a bigger problem and connect all the at the end.  "Before, abstract Math is today\'s proven science". Some ideas can be abstract now. However, it might be proven by other scientists in the future. So it is important to get a development.  With abstraction, we can understand things that difficult to understand. Approximation law by infinity, instant change, abstract predict interest, approximation, 
# ...

# %%
with open("/content/drive/MyDrive/Colab Notebooks/NLP_PROJECT/QAs-3.txt",'w+') as my_file:
  my_file.write(text)

# %%
text = text.replace(" . "," ")
text
# Out:
# ' Abstraction is generalizing concepts. Engineers can use this for calculating abstract things. This helps for engineers to solving abstract problems. Abstraction is useful for think easily.  "Invested Zero and then invested number. First binary system. Then we calculate some science and math problems with this invested ".  There is a famous line today\'s abstract math is tomorrow\'s applied, Which means that we developed math and better way to express things with abstract math.  Abstraction is one of the greatest tool of the engineer. By abstracting a problem we can solve little pieces of a bigger problem and connect all the at the end.  "Before, abstract Math is today\'s proven science". Some ideas can be abstract now. However, it might be proven by other scientists in the future. So it is important to get a development.  With abstraction, we can understand things that difficult to understand. Approximation law by infinity, instant change, abstract predict interest, approximation, 
# ...

# %%
with open("/content/drive/MyDrive/Colab Notebooks/NLP_PROJECT/QAs-3.txt",'w+') as my_file:
  my_file.write(text)

# %%
text = text.replace(" ,, "," ")
text
# Out:
# ' Abstraction is generalizing concepts. Engineers can use this for calculating abstract things. This helps for engineers to solving abstract problems. Abstraction is useful for think easily.  "Invested Zero and then invested number. First binary system. Then we calculate some science and math problems with this invested ".  There is a famous line today\'s abstract math is tomorrow\'s applied, Which means that we developed math and better way to express things with abstract math.  Abstraction is one of the greatest tool of the engineer. By abstracting a problem we can solve little pieces of a bigger problem and connect all the at the end.  "Before, abstract Math is today\'s proven science". Some ideas can be abstract now. However, it might be proven by other scientists in the future. So it is important to get a development.  With abstraction, we can understand things that difficult to understand. Approximation law by infinity, instant change, abstract predict interest, approximation, 
# ...

# %%
with open("/content/drive/MyDrive/Colab Notebooks/NLP_PROJECT/QAs-3.txt",'w+') as my_file:
  my_file.write(text)

# %%
text = text.replace(" , "," ")
text
# Out:
# ' Abstraction is generalizing concepts. Engineers can use this for calculating abstract things. This helps for engineers to solving abstract problems. Abstraction is useful for think easily.  "Invested Zero and then invested number. First binary system. Then we calculate some science and math problems with this invested ".  There is a famous line today\'s abstract math is tomorrow\'s applied, Which means that we developed math and better way to express things with abstract math.  Abstraction is one of the greatest tool of the engineer. By abstracting a problem we can solve little pieces of a bigger problem and connect all the at the end.  "Before, abstract Math is today\'s proven science". Some ideas can be abstract now. However, it might be proven by other scientists in the future. So it is important to get a development.  With abstraction, we can understand things that difficult to understand. Approximation law by infinity, instant change, abstract predict interest, approximation, 
# ...

# %%
with open("/content/drive/MyDrive/Colab Notebooks/NLP_PROJECT/QAs-3.txt",'w+') as my_file:
  my_file.write(text)

# %%
with open("/content/drive/MyDrive/Colab Notebooks/NLP_PROJECT/QAs-3.txt") as f:
  text = f.read()

# %%
text = text.replace("  ", " ")
text
# Out:
# ' Abstraction is generalizing concepts. Engineers can use this for calculating abstract things. This helps for engineers to solving abstract problems. Abstraction is useful for think easily. "Invested Zero and then invested number. First binary system. Then we calculate some science and math problems with this invested ". There is a famous line today\'s abstract math is tomorrow\'s applied, Which means that we developed math and better way to express things with abstract math. Abstraction is one of the greatest tool of the engineer. By abstracting a problem we can solve little pieces of a bigger problem and connect all the at the end. "Before, abstract Math is today\'s proven science". Some ideas can be abstract now. However, it might be proven by other scientists in the future. So it is important to get a development. With abstraction, we can understand things that difficult to understand. Approximation law by infinity, instant change, abstract predict interest, approximation, senat
# ...

# %%
with open("/content/drive/MyDrive/Colab Notebooks/NLP_PROJECT/QAs-3.txt",'w+') as my_file:
  my_file.write(text)
