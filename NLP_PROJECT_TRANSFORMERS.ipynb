# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
with open("/content/drive/MyDrive/Colab Notebooks/NLP_PROJECT/QAs-3.txt") as f:
  text = f.read()

# %% [markdown]
# 1-) GET USER PROVIDED ANSWERS

# %%
user_text = input("Enter a text: ")
print(user_text)
# Out:
# Enter a text: Abstraction is a general concept which you can find in the real world as well as in OOP languages.
# Abstraction is a general concept which you can find in the real world as well as in OOP languages.

# %%
user_text_2 = input("Enter a text: ")
print(user_text_2)
# Out:
# Enter a text: Abstraction (from the Latin abs, meaning away from and trahere , meaning to draw) is the process of taking away or removing characteristics from something
# Abstraction (from the Latin abs, meaning away from and trahere , meaning to draw) is the process of taking away or removing characteristics from something

# %% [markdown]
# 2-) USE TRANSFORMERS AND CALCULATE SIMILARITY

# %%
# !pip install -U sentence-transformers

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('sentence-transformers/bert-base-nli-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.95k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/399 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
sentences = [user_text,user_text_2,text]

# %%
sentence_embeddings = model.encode(sentences)

# %%
sentence_embeddings.shape
# Out:
# (3, 768)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
sentence_embeddings[0]

# %%
cosine_similarity(
    [sentence_embeddings[0]],
    sentence_embeddings[2:]
)
# Out:
# array([[0.4877171]], dtype=float32)

# %%
cosine_similarity(
    [sentence_embeddings[1]],
    sentence_embeddings[2:]
)
# Out:
# array([[0.31037647]], dtype=float32)
